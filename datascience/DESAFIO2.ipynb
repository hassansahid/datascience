# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
playerfutbol_df = pd.read_csv("./archivos/Fifa 23 Fut Players.csv")

# %% [markdown]
# ####Guía Posiciones de Jugadores Fifa 23
# Posición    Abreviatura (ING)
#
# #ARQUERO
# Portero	GK
#
# #DEFENSA
# Carrilero Derecho RWB
# Lateral Derecho RB
# Defensa Central	CB
# Lateral Izquierdo LF
#
# #VOLANTE
# Carrilero Izquierdo LWB
# Medio Centro Defensivo CDM
# Medio Derecho RM
# Medio Centro CM
# Medio Izquierdo LM
# Medio Centro Ofensivo CAM
#
# #DELANTERO
# Segundo Delantero Derecho RF
# Media Punta CF
# Segundo Delantero Izquierdo LF
# Extremo Derecho RW
# Delantero Centro ST
# Extremo Izquierdo LW

# %%
normalsplayers = playerfutbol_df[playerfutbol_df.Version.str.contains('Normal')]

# %%
normalsplayers = normalsplayers[["Name", "Ratings", "Position", "PS", "Country"]]

# %%
argentinaPlayers = normalsplayers[normalsplayers.Country.str.contains('Argentina')]
inglaterraPlayers = normalsplayers[normalsplayers.Country.str.contains('England')]
brasilPlayers = normalsplayers[normalsplayers.Country.str.contains('Brazil')]
espanaPlayer = normalsplayers[normalsplayers.Country.str.contains('Spain')]
franciaPlayer = normalsplayers[normalsplayers.Country.str.contains('France')]
alemaniaPlayer = normalsplayers[normalsplayers.Country.str.contains('Germany')]

# %%
lautarodf = playerfutbol_df[playerfutbol_df.Version.str.contains('Icon')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21452/13038207.py in <module>
# ----> 1 lautarodf = playerfutbol_df[playerfutbol_df.Version.str.drop('Icon')]
#
# AttributeError: 'StringMethods' object has no attribute 'drop'

# %%
lautarodf
# Out:
#                        Name  Ratings    Position           Version    PS  SKI  \
# 0                      Pelé       98         CAM   Icon  Explosive     0    5
# 1                   Ronaldo       96          ST  Icon  Controlled     0    5
# 2           Zinedine Zidane       96         CAM  Icon  Controlled     0    5
# 3                      Pelé       95  CF  CAM,ST   Icon  Explosive  4.2M    5
# 4             Ferenc Puskás       94          CF  Icon  Controlled     0    4
# ..                      ...      ...         ...               ...   ...  ...
# 483           Rio Ferdinand       85          CB     Icon  Lengthy  350K    3
# 484            Robert Pirès       85     CAM  LM  Icon  Controlled   72K    4
# 485           Ronald Koeman       85          CB     Icon  Lengthy   84K    3
# 486  Rui Manuel César Costa       85         CAM  Icon  Controlled   79K    4
# 487            Sol Campbell       85          CB     Icon  Lengthy  229K    2
#
# ...
