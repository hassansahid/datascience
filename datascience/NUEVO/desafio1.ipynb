# %%
import pandas as pd

# %%
futbol_df = pd.read_csv("../archivos/Fifa 23 Fut Players.csv")

# %%
futbol_df.head(50)
# Out:
#                       Name  Ratings    Position           Version     PS  SKI  \
# 0                     Pelé       98         CAM   Icon  Explosive      0    5
# 1                  Ronaldo       96          ST  Icon  Controlled      0    5
# 2          Zinedine Zidane       96         CAM  Icon  Controlled      0    5
# 3                     Pelé       95  CF  CAM,ST   Icon  Explosive   4.2M    5
# 4            Ferenc Puskás       94          CF  Icon  Controlled      0    4
# 5             Johan Cruyff       94          CF   Icon  Explosive      0    5
# 6               Lev Yashin       94          GK  Icon  Controlled      0    1
# 7           Mané Garrincha       94          RW   Icon  Explosive      0    5
# 8            Paolo Maldini       94          CB     Icon  Lengthy      0    2
# 9               Ronaldinho       94          LW  Icon  Controlled      0    5
# 10                 Ronaldo       94      ST  CF  Icon  Controlled   8.5M    5
# ...

# %%
num_filas = futbol_df.shape[0]
num_columnas = futbol_df.shape[1]

print(f"El archivo tiene {num_filas} filas y {num_columnas} columnas.")
# Out:
# El archivo tiene 16456 filas y 21 columnas.
