# %% [markdown]
# En este Notebook se buscara explorar y analizar diferentes Datasets para determinar su viabilidad para el proyecto

# %%
import pandas as pd

# %% [markdown]
# El primer DataSet que analice fue relacionado los jugadores del FIFA 23 . Se analiza cuantas cartas de Lionel Messi aparecen en el juego y si esta dentro del Top 10.

# %%
playerfutbol_df = pd.read_csv("./archivos/Fifa 23 Fut Players.csv")

# %% [markdown]
# LINK "https://www.kaggle.com/datasets/mohammedessam97/fifa-23-fut-players-dataset"
#
# Columns Description
# here is a description of some columns in the dataset :
#
# Ratings : Player Rating
# Position : Player Position
# Version : Card Version
# PS : Price on Playstation , if 0 then it is not available in market
# SKI : Skills rating of player ( from 0 to 5 )
# WF : Weak Foot Skills ( from 0 to 5 )
# WR : Work rate of player on the field , and given in the formula ( Attack Work rate / Defence Work rate ) , each value can be ( low , medium , high )
# PAC : Player Pace (Speed)
# SHO : Player Shooting power
# PAS : Player Pass
# DRI : Player Dribble
# DEF : Player Defence
# PHY : Player Physicality
# Body : player height given in cm and feet followed by type of body of player ( for some players the game have custom body for them )
# Popularity : popularity of using the player
# BS : Base stats
# IGS : In game stats

# %%
playerfutbol_df.head(10)
# Out:
#               Name  Ratings    Position           Version    PS  SKI  WF  \
# 0             Pelé       98         CAM   Icon  Explosive     0    5   4
# 1          Ronaldo       96          ST  Icon  Controlled     0    5   5
# 2  Zinedine Zidane       96         CAM  Icon  Controlled     0    5   5
# 3             Pelé       95  CF  CAM,ST   Icon  Explosive  4.2M    5   4
# 4    Ferenc Puskás       94          CF  Icon  Controlled     0    4   3
# 5     Johan Cruyff       94          CF   Icon  Explosive     0    5   5
# 6       Lev Yashin       94          GK  Icon  Controlled     0    1   3
# 7   Mané Garrincha       94          RW   Icon  Explosive     0    5   4
# 8    Paolo Maldini       94          CB     Icon  Lengthy     0    2   4
# 9       Ronaldinho       94          LW  Icon  Controlled     0    5   4
#
#       WR  PAC  SHO  ...  DRI  DEF  PHY                                 Body  \
# 0  H \ M   95   96  ...   96   60   76          173cm | 5'8"  Unique (70kg)
# ...

# %%
playerfutbol_df.shape
# Out:
# (16456, 21)

# %%
playerfutbol_df.dtypes
# Out:
# Name          object
# Ratings        int64
# Position      object
# Version       object
# PS            object
# SKI            int64
# WF             int64
# WR            object
# PAC            int64
# SHO            int64
# PAS            int64
# DRI            int64
# DEF            int64
# PHY            int64
# Body          object
# Popularity     int64
# BS             int64
# IGS           object
# Club          object
# League        object
# Country       object
# dtype: object

# %%
playerfutbol_df.describe()
# Out:
#             Ratings           SKI            WF           PAC           SHO  \
# count  16456.000000  16456.000000  16456.000000  16456.000000  16456.000000
# mean      66.979278      2.410246      2.974781     68.671123     54.997265
# std        7.710202      0.808773      0.699982     11.147725     14.371595
# min       46.000000      0.000000      0.000000     28.000000     18.000000
# 25%       62.000000      2.000000      3.000000     62.000000     45.000000
# 50%       66.000000      2.000000      3.000000     69.000000     57.000000
# 75%       71.000000      3.000000      3.000000     76.000000     65.000000
# max       98.000000      5.000000      5.000000     99.000000     96.000000
#
#                 PAS           DRI           DEF           PHY    Popularity  \
# count  16456.000000  16456.000000  16456.000000  16456.000000  16456.000000
# mean      59.206125     64.247022     51.095831     65.877613     25.914864
# ...

# %%
playerfutbol_df.isnull().sum()
# Out:
# Name          0
# Ratings       0
# Position      0
# Version       0
# PS            0
# SKI           0
# WF            0
# WR            0
# PAC           0
# SHO           0
# PAS           0
# DRI           0
# DEF           0
# PHY           0
# Body          1
# Popularity    0
# BS            0
# IGS           0
# Club          0
# League        0
# Country       0
# dtype: int64

# %%
playerfutbol_df = playerfutbol_df[playerfutbol_df['Name'] == "Lionel Messi"]

# %%
playerfutbol_df
# Out:
#              Name  Ratings Position                      Version       PS  \
# 50   Lionel Messi       92   RW  RM  Champions League  Explosive    1.38M
# 51   Lionel Messi       92      CAM  Ligue 1 POTM SBC  Explosive  741.25K
# 100  Lionel Messi       91   RW  RM            Normal  Explosive     247K
#
#      SKI  WF     WR  PAC  SHO  ...  DRI  DEF  PHY                        Body  \
# 50     4   4  L \ L   82   90  ...   95   35   66  169cm | 5'7"  Messi (67kg)
# 51     4   4  L \ L   82   90  ...   95   35   65  169cm | 5'7"  Messi (67kg)
# 100    4   4  L \ L   81   89  ...   94   34   64  169cm | 5'7"  Messi (67kg)
#
#     Popularity   BS   IGS      Club   League    Country
# 50        1066  460  2271  Paris SG  Ligue 1  Argentina
# 51        3020  458  2262  Paris SG  Ligue 1  Argentina
# 100       1128  452  2232  Paris SG  Ligue 1  Argentina
#
# [3 rows x 21 columns]

# %% [markdown]
# El segundo DataSet que analice fue realacionado con el Bitcoin, el precio actual, sobre su maximo, la fecha del mismo y su valor medio desde su existencia.

# %%
bitcoindf = pd.read_csv("./archivos/coin_Bitcoin.csv")

# %% [markdown]
# Link = https://www.kaggle.com/datasets/sudalairajkumar/cryptocurrencypricehistory
#
# Content El historial de precios está disponible diariamente desde el 28 de abril de 2013. Este conjunto de datos tiene la información histórica de precios de algunas de las principales criptomonedas por capitalización de mercado.
#
# Date : fecha de la observación
# Open : precio de apertura en el día
# High : precio más alto en el día
# Low : precio más bajo en el día
# Close : precio más bajo en el día
# Volume : Volumen de transacciones en el día
# Market Cap : Volumen de transacciones en el día

# %%
bitcoindf.head(20)
# Out:
#     SNo     Name Symbol                 Date        High         Low  \
# 0     1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1     2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2904  2905  Bitcoin    BTC  2021-04-11 23:59:59  60790.555315  59289.795631
# ...

# %%
bitcoindf.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %% [markdown]
# Como Tercer DataSets seleccione uno sobre peliculas / series de Netflix , buscar "Breaking Bad" , Ver cuantas peliculas hay y cuantas series

# %%
import pandas as pd

# %%
pelistodas = pd.read_csv("./archivos/netflix_titles.csv")

# %%
pelistodas.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
pelistodas  .isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
pelistodas.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
pelistodas = pelistodas[pelistodas['title'] == "Breaking Bad"]

# %%
pelistodas
# Out:
#      show_id     type         title director  \
# 5940   s5941  TV Show  Breaking Bad      NaN
#
#                                                    cast        country  \
# 5940  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
#
#           date_added  release_year rating   duration  \
# 5940  August 2, 2013          2013  TV-MA  5 Seasons
#
#                                     listed_in  \
# 5940  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 5940  A high school chemistry teacher dying of cance...

# %%
pelistodas = pelistodas[pelistodas["type"] == "TV Show"]

# %%
cantSeries = len(pelistodas.axes[0])

# %%
print("Cantidad de series :" + str(cantSeries))
# Out:
# Cantidad de series :2676

# %%
pelistodas = pelistodas[pelistodas["type"] == "Movie"]

# %%
print("Cantidad de Peliculas: ", pelistodas.shape[0])
# Out:
# Cantidad de Peliculas:  6131
